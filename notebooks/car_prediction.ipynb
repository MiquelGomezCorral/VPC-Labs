# %% [markdown]
# # Import setting

# %%
# %load_ext autoreload
# %autoreload 2

from src.config import Configuration

CONFIG = Configuration()
# Out:
# ________________________________________________________________________________________________________________________________
#                                                          CONFIGURATION
#
# Experiment description: Base experiment description
# Experiment name: base_name
# Model type: small
# seed: 42
# batch_size: 128
# epochs: 100
# dropout_rate: 0.5
# label_smoothing: 0.1
# learning_rate: 0.01
# weight_decay: 0.0001
# eta_min: 1e-06
# momentum: 0.9
# lr_reduce_factor: 0.5
# lr_patience: 3
# patience: 10

# %% [markdown]
# # Load data

# %% [markdown]
# Successfully installed app-0.1.0
#    VPC_env turbotowerlnx@turbotowerlnx ~/..../VPC-Labs  main  tree -L 4
# .
# ├── app
# │   ├── __init__.py
# │   ├── main.py
# │   ├── scripts
# │   │   ├── car.py
# │   │   ├── gender.py
# │   │   ├── __init__.py
# │   └── src
# │       ├── config
# │       │   ├── config.py
# │       │   ├── __init__.py
# │       │   └── __pycache__
# │       ├── data
# │       │   ├── gender.py
# │       │   ├── __init__.py
# │       │   └── __pycache__
# │       ├── models
# │       │   ├── gender.py
# │       │   ├── __init__.py
# │       │   └── __pycache__
# │       └── utils
# │           └── __init__.py
# ├── data
# │   ├── car
# │   │   ├── data.tgz
# │   │   ├── x_test.npy
# │   │   ├── x_train.npy
# │   │   ├── y_test.npy
# │   │   └── y_train.npy
# │   └── gender
# │       ├── gender.tgz
# │       ├── x_test.npy
# │       ├── x_train.npy
# │       ├── y_test.npy
# │       └── y_train.npy
# ├── docs
# ├── example.env
# ├── LICENSE
# ├── logs
# │   └──...
# ├── models
# │   ├── ...
# │   └── gender-large-epoch=71-val_acc=0.9607.ckpt
# ├── notebooks
# │   ├── car_prediction.ipynb
# │   ├── gender_prediction.ipynb
# │   └── gender_roberto.ipynb
# ├── pyproject.toml
# ├── README.md
# └── requirements.txt

# %%
from src.data import load_gender_data

train_loader, test_loader = load_gender_data(CONFIG, use_transforms=False)

# %%
import numpy as np

x_train = np.load(CONFIG.gender_x_train)
x_test = np.load(CONFIG.gender_x_test)

y_train = np.load(CONFIG.gender_y_train)
y_test = np.load(CONFIG.gender_y_test)

# %% [markdown]
# # Load models
