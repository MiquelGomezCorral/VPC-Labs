# %% [markdown]
# # INITIAL IMPORT

# %%
import os

print(os.getcwd())
if not os.getcwd().endswith("app"):
    os.chdir("../app")
    print(os.getcwd())

# %load_ext autoreload
# %autoreload 2
# Out:
# /home/turbotowerlnx/Documents/Master/TLH/TLH-CharoCharito-Alexa/app
